# %%
# !pip install pfhedge
# Out:
# Collecting pfhedge
#   Downloading pfhedge-0.23.0-py3-none-any.whl.metadata (805 bytes)
# Requirement already satisfied: numpy<2.0,>=1.26 in /usr/local/lib/python3.10/dist-packages (from pfhedge) (1.26.4)
# Requirement already satisfied: torch<3.0.0,>=1.9.0 in /usr/local/lib/python3.10/dist-packages (from pfhedge) (2.4.1+cu121)
# Requirement already satisfied: tqdm<5.0.0,>=4.62.3 in /usr/local/lib/python3.10/dist-packages (from pfhedge) (4.66.5)
# Requirement already satisfied: filelock in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=1.9.0->pfhedge) (3.16.1)
# Requirement already satisfied: typing-extensions>=4.8.0 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=1.9.0->pfhedge) (4.12.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=1.9.0->pfhedge) (1.13.3)
# Requirement already satisfied: networkx in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=1.9.0->pfhedge) (3.3)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=1.9.0->pfhedge) (3.1.4)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.10/dist-packages (from torch<3.0.0,>=1.9.0->pfhedge) (2024.6.1)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.10/dist-packages (from jinja2->torch<3.0.0,>=1.9.0->pfhedge) (2.1.5)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.10/dist-packages (from sympy->torch<3.0.0,>=1.9.0->pfhedge) (1.3.0)
# Downloading pfhedge-0.23.0-py3-none-any.whl (105 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 105.1/105.1 kB 2.1 MB/s eta 0:00:00
# Installing collected packages: pfhedge
# Successfully installed pfhedge-0.23.0

# %% [markdown]
# #@Deep hedging in pytorch

# %%
from pfhedge.instruments import BrownianStock

# %%
stock = BrownianStock()

# %%
stock
# Out:
# BrownianStock(sigma=0.2000, dt=0.0040)

# %%
#@title Defining a class fuction
class Tensor():
    pass

# %%
class Tensor:
    pass

# %%
Tensor()

# %%
Tensor()

# %%
BrownianStock()
# Out:
# BrownianStock(sigma=0.2000, dt=0.0040)

# %%
#@title <__main__.Tensor at 0x79dc9fc18550> ??

# %%
print(Tensor())
a= Tensor()
print(a)
print(Tensor)
# Out:
# <__main__.Tensor object at 0x79dc93685b40>
# <__main__.Tensor object at 0x79dc93686740>
# <class '__main__.Tensor'>

# %%
BrownianStock()
# Out:
# BrownianStock(sigma=0.2000, dt=0.0040)

# %%
#@title **__repr__**
class Tensor:

    def __repr__(self):
        return "Tensor instance"

Tensor()
# Out:
# Tensor instance

# %%
BrownianStock(cost=0.0)
# Out:
# BrownianStock(sigma=0.2000, dt=0.0040)

# %%
#@title __init__
class Tensor:
    def __init__(self, data):
        self.data = data
    def __repr__(self):
        return f"Tensor with {self.data}"

# %%
Tensor(1.0)
# Out:
# Tensor with 1.0

# %%
a = Tensor(1.0)
a
# Out:
# Tensor with 1.0

# %%
print(a.data)
a.data = 2
a
# Out:
# 2
# Tensor with 2

# %%
a= Tensor(1.0)
b= Tensor(2.0)
a,b
# Out:
# (Tensor with 1.0, Tensor with 2.0)

# %%
a+b
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-29-ca730b97bf8a> in <cell line: 1>()
# ----> 1 a+b
#
# TypeError: unsupported operand type(s) for +: 'Tensor' and 'Tensor'

# %%
#@title ** __add__**
class Tensor:
    def __init__(self,data):
        self.data = data
    def __add__(self, other):
        out = Tensor(self.data + other.data)
        return out
    def __repr__(self):
        return f"Tensor with {self.data}"

# %%
a= Tensor(1.0)
b= Tensor(2.0)

# %%
a ,  b
# Out:
# (Tensor with 1.0, Tensor with 2.0)

# %%
(a +b)
# Out:
# Tensor with 3.0

# %%
#@title Self ???

# %%
print(a. __add__(b))

print(b. __repr__())
print(a.data)
print(b.data)
# Out:
# Tensor with 3.0
# Tensor with 2.0
# 1.0
# 2.0

# %% [markdown]
# # List

# %%
[1,2,3]+ [4,5]
# Out:
# [1, 2, 3, 4, 5]

# %%
[1,2,3,].__add__([4,5])
# Out:
# [1, 2, 3, 4, 5]

# %% [markdown]
# # __mul__

# %%
class Tensor:
    def __init__(self,data):
        self.data = data
    def __add__(self,other):
        out = Tensor(self.data + other.data)
        return out
    def __mul__(self, other):
        out = Tensor(self.data * other.data)
        return out
    def __repr__(self):
        return f"Tensor with {self.data}"

# %%
a= Tensor(1.0)
b= Tensor(2.0)
c= Tensor(5.0)
print((a+b))
print((a*b))
print((a+b)*c)
# Out:
# Tensor with 3.0
# Tensor with 2.0
# Tensor with 15.0

# %%
(a.__add__(b)).__mul__(c)
# Out:
# Tensor with 15.0

# %%
a + 1.0
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-63-3e15d59f2191> in <cell line: 1>()
# ----> 1 a + 1.0
#
# <ipython-input-54-1ac49d76c2af> in __add__(self, other)
#       3         self.data = data
#       4     def __add__(self,other):
# ----> 5         out = Tensor(self.data + other.data)
#       6         return out
#       7     def __mul__(self, other):
#
# AttributeError: 'float' object has no attribute 'data'

# %%
isinstance(1.0, Tensor)
# Out:
# False

# %% [markdown]
# # Upgrade

# %%
class Tensor:
    def __init__(self,data):
        self.data = data
    def __add__(self,other):
        other = other if isinstance(other, Tensor) else Tensor(other)
        out = Tensor(self.data + other.data)
        return out

    def __mul__(self, other):
        other = other if isinstance(other, Tensor) else Tensor(other)
        out = Tensor(self.data * other.data)
        return
    def __repr__(self):
        return f"Tensor with {self.data}"

# %%
a = Tensor(1.0)
print(a +1)
print(a +2)
a.__add__(2)
# Out:
# Tensor with 2.0
# Tensor with 3.0
# Tensor with 3.0

# %%
1 +a
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-70-4828a400ccb0> in <cell line: 1>()
# ----> 1 1 +a
#
# TypeError: unsupported operand type(s) for +: 'int' and 'Tensor'

# %%
class Tensor:
    def __init__(self, data):
        self.data = data

    def __add__(self, other):
        other = other if isinstance(other, Tensor) else Tensor(other)
        out = Tensor(self.data + other.data)
        return out

    def __mul__(self, other):
        other = other if isinstance(other, Tensor) else Tensor(other)
        out = Tensor(self.data * other.data)
        return out

    def __radd__(self, other):
        print(self, other)
        return self + other

    def __repr__(self):
        return f"Tensor with {self.data}"

# %%
a = Tensor(1.0)

1 +a
# Out:
# Tensor with 1.0 1
# Tensor with 2.0

# %%
a = Tensor(1.0)
20 + a
# Out:
# Tensor with 1.0 20
# Tensor with 21.0

# %%
class Tensor:
    def __init__(self, data):
        self.data = data

    def __add__(self, other):
        other = other if isinstance(other, Tensor) else Tensor(other)
        out = Tensor(self.data + other.data)
        return out

    def __mul__(self, other):
        other = other if isinstance(other, Tensor) else Tensor(other)
        out = Tensor(self.data * other.data)
        return out

    def __radd__(self, other):
        return self + other

    def __rmul__(self, other):
        return self * other

    def __repr__(self):
        return f"Tensor with {self.data}"

# %%
import numpy as np

# %% [markdown]
# # Self.prev

# %%
class Tensor:

    def __init__(self, data, prev=()):
        self.data = data
        self.prev = prev

    def __add__(self, other):
        other = other if isinstance(other, Tensor) else Tensor(other)
        out = Tensor(self.data + other.data, prev=(self, other))
        return out

    def __mul__(self, other):
        other = other if isinstance(other, Tensor) else Tensor(other)
        out = Tensor(self.data * other.data, prev=(self, other))
        return out

    def __radd__(self, other):
        return self + other

    def __rmul__(self, other):
        return self * other

    def relu(self):
        return Tensor(np.maximum(self.data, 0), prev=(self,))

    def __repr__(self):
        return f"Tensor(data={self.data}, prev={self.prev})"

# %%
print(Tensor(1.0) + Tensor(2.0))

print((Tensor(1.0) + Tensor(2.0)) * Tensor(5.0))
# Out:
# Tensor(data=3.0, prev=(Tensor(data=1.0, prev=()), Tensor(data=2.0, prev=())))
# Tensor(data=15.0, prev=(Tensor(data=3.0, prev=(Tensor(data=1.0, prev=()), Tensor(data=2.0, prev=()))), Tensor(data=5.0, prev=())))

# %%
a = Tensor(1.0)
b = Tensor(2.0)
c = Tensor(-5.0)

# %%
((a + b) * c).relu()
# Out:
# Tensor(data=0.0, prev=(Tensor(data=-15.0, prev=(Tensor(data=3.0, prev=(Tensor(data=1.0, prev=()), Tensor(data=2.0, prev=()))), Tensor(data=-5.0, prev=()))),))
