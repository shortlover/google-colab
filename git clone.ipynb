# %%
from google.colab import drive
drive.mount('/content/drive')

# %%
GIT_token = "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"
GIT_username = "shortlover"
GIT_repo = "google-colab"
GIT_path = f"https://{GIT_username}:{GIT_token}@github.com/{GIT_username}/{GIT_repo}.git"
print(GIT_path)

# %%
from os.path import join

PROJ_path = "/content/drive/MyDrive/Colab Notebooks"
# %cd {PROJ_path}
# !git clone {GIT_path}

# %%
cd /content/drive/MyDrive/Colab Notebooks/google-colab

# %%
# !git config --global user.email 'blblwh1633@gmail.com'
# !git config --global user.name 'shortlover'

# %%
# !git add all
